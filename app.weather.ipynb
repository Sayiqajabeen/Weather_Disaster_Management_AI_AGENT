# %%
import os
from dotenv import load_dotenv

# Load from .env file in the same directory
load_dotenv()

# Get environment variables
gemini_api_key = os.getenv("GEMINI_API_KEY")
API_KEY = os.getenv("W_API_KEY")

# Check if keys are present
if not gemini_api_key or not API_KEY:
    raise ValueError("Missing API keys in .env file. Please check GEMINI_API_KEY and W_API_KEY.")

# Optionally set them to os.environ
os.environ["API_KEY"] = API_KEY
os.environ["GOOGLE_API_KEY"] = gemini_api_key

# %%
import os
import random
import requests
import schedule
import time
from typing import Dict, TypedDict, Union, List, Literal
import json
from datetime import datetime
from langgraph.graph import StateGraph, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %% [markdown]
# Defining an LLM and a State Class

# %%
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

class WeatherState(TypedDict):
    city: str
    weather_data: Dict
    disaster_type: str
    severity: str
    response: str
    messages: List[Union[SystemMessage, HumanMessage, AIMessage]]
    alerts: List[str]
    human_approved: bool

# %% [markdown]
# 5. Define Node Functions
# (a) Fetching Weather Data

# %%
def get_weather_data(state: WeatherState) -> Dict:
    """Fetch weather data from OpenWeatherMap API"""
    BASE_URL = "http://api.openweathermap.org/data/2.5/weather"
    API_KEY = os.getenv("API_KEY")

    request_url = f"{BASE_URL}?appid={API_KEY}&q={state['city']}"
    try:
        response = requests.get(request_url)
        response.raise_for_status()

        data = response.json()
        weather_data = {
            "weather": data.get('weather', [{}])[0].get("description", "N/A"),
            "wind_speed": data.get("wind", {}).get("speed", "N/A"),
            "cloud_cover": data.get("clouds", {}).get("all", "N/A"),
            "sea_level": data.get("main", {}).get("sea_level", "N/A"),
            "temperature": round(data.get("main", {}).get("temp", 273.15) - 273.15, 1),
            "humidity": data.get("main", {}).get("humidity", "N/A"),
            "pressure": data.get("main", {}).get("pressure", "N/A")
        }

        return {
            **state,
            "weather_data": weather_data,
            "messages": state["messages"] + [SystemMessage(content=f"Weather data fetched successfully for {state['city']}")]
        }

    except Exception as e:
        error_data = {
            "weather": "N/A",
            "wind_speed": "N/A",
            "cloud_cover": "N/A",
            "sea_level": "N/A",
            "temperature": "N/A",
            "humidity": "N/A",
            "pressure": "N/A"
        }
        return {
            **state,
            "weather_data": error_data,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to fetch weather data for {state['city']}: {str(e)}")]
        }

# %% [markdown]
# (b) Disaster Type Analysis

# %%
def analyze_disaster_type(state: WeatherState) -> WeatherState:
    """Analyze weather data to identify potential disasters"""
    weather_data = state["weather_data"]
    prompt = ChatPromptTemplate.from_template(
        "Based on the following weather conditions, identify if there's a potential weather disaster.\n"
        "Weather conditions:\n"
        "- Description: {weather}\n"
        "- Wind Speed: {wind_speed} m/s\n"
        "- Temperature: {temperature}°C\n"
        "- Humidity: {humidity}%\n"
        "- Pressure: {pressure} hPa\n"
        "Categorize into one of these types: Hurricane, Flood, Heatwave, Severe Storm, Winter Storm, or No Immediate Threat"
    )

    try:
        chain = prompt | llm
        disaster_type = chain.invoke(weather_data).content
        return {
            **state,
            "disaster_type": disaster_type,
            "messages": state["messages"] + [SystemMessage(content=f"Disaster type identified: {disaster_type}")]
        }
    except Exception as e:
        return {
            **state,
            "disaster_type": "Analysis Failed",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to analyze disaster type: {str(e)}")]
        }

# %% [markdown]
# (c) Severity Assessment

# %%
def assess_severity(state: WeatherState) -> WeatherState:
    """Assess the severity of the identified weather situation"""
    weather_data = state["weather_data"]
    prompt = ChatPromptTemplate.from_template(
        "Given the weather conditions and identified disaster type '{disaster_type}', "
        "assess the severity level. Consider:\n"
        "- Weather: {weather}\n"
        "- Wind Speed: {wind_speed} m/s\n"
        "- Temperature: {temperature}°C\n"
        "Respond with either 'Critical', 'High', 'Medium', or 'Low'"
    )

    try:
        chain = prompt | llm
        severity = chain.invoke({
            **weather_data,
            "disaster_type": state["disaster_type"]
        }).content

        return {
            **state,
            "severity": severity,
            "messages": state["messages"] + [SystemMessage(content=f"Severity assessed as: {severity}")]
        }
    except Exception as e:
        return {
            **state,
            "severity": "Assessment Failed",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to assess severity: {str(e)}")]
        }

# %% [markdown]
# (d) Emergency Response Plan

# %%
def emergency_response(state: WeatherState) -> WeatherState:
    """Generate emergency response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create an emergency response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Include immediate actions needed."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Emergency response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate emergency response: {str(e)}")]
        }

# %% [markdown]
# (e) Civil Defense Response

# %%
def civil_defense_response(state: WeatherState) -> WeatherState:
    """Generate civil defense response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create a civil defense response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Focus on public safety measures."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Civil defense response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate civil defense response: {str(e)}")]
        }

# %% [markdown]
# (f) Public Works Response

# %%
def public_works_response(state: WeatherState) -> WeatherState:
    """Generate public works response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create a public works response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Focus on infrastructure protection."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Public works response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate public works response: {str(e)}")]
        }

# %% [markdown]
# (g) Data Logging

# %%
def data_logging(state: WeatherState) -> WeatherState:
    """Log weather data, disaster analysis, and response to a file."""
    log_data = {
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "city": state["city"],
        "weather_data": state["weather_data"],
        "disaster_type": state["disaster_type"],
        "severity": state["severity"],
        "response": state["response"],
    }

    try:
        with open("disaster_log.txt", "a") as log_file:
            log_file.write(json.dumps(log_data) + "\n")

        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content="Data logged successfully")]
        }
    except Exception as e:
        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to log data: {str(e)}")]
        }

# %% [markdown]
# (h) Human Verification

# %%
def get_human_verification(state: WeatherState) -> WeatherState:
    """Get human verification for low/medium severity alerts"""
    severity = state["severity"].strip().lower()

    if severity in ["low", "medium"]:
        print("\n" + "="*50)
        print(f"Low/Medium severity alert for {state['city']} requires human approval:")
        print(f"Disaster Type: {state['disaster_type']}")
        print(f"Current Weather: {state['weather_data']['weather']}")
        print(f"Temperature: {state['weather_data']['temperature']}°C")
        print(f"Wind Speed: {state['weather_data']['wind_speed']} m/s")
        print(f"Severity: {state['severity']}")
        print(f"Response Plan: {state['response']}")
        print("\nType 'y' to approve sending alert or 'n' to reject (waiting for input):")
        print("="*50)

        # Block and wait for input
        while True:
            try:
                user_input = input().lower().strip()
                if user_input in ['y', 'n']:
                    approved = user_input == 'y'
                    print(f"Human verification result: {'Approved' if approved else 'Rejected'}")
                    break
                else:
                    print("Please enter 'y' for yes or 'n' for no:")
            except Exception as e:
                print(f"Error reading input: {str(e)}")
                print("Please try again with 'y' or 'n':")

        return {
            **state,
            "human_approved": approved,
            "messages": state["messages"] + [
                SystemMessage(content=f"Human verification: {'Approved' if approved else 'Rejected'}")
            ]
        }
    else:
        # Auto-approve for high/critical severity
        return {
            **state,
            "human_approved": True,
            "messages": state["messages"] + [
                SystemMessage(content=f"Auto-approved {severity} severity alert")
            ]
        }

# %% [markdown]
# (j) Email Alert

# %%
def send_email_alert(state: WeatherState) -> WeatherState:
    """Send weather alert email"""
    sender_email = os.getenv("SENDER_EMAIL")
    receiver_email = os.getenv("RECEIVER_EMAIL")
    password = os.getenv("EMAIL_PASSWORD")

    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = f"Weather Alert: {state['severity']} severity weather event in {state['city']}"

    body = format_weather_email(state)
    msg.attach(MIMEText(body, 'plain'))

    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, password)
        text = msg.as_string()
        server.sendmail(sender_email, receiver_email, text)
        server.quit()

        # Add confirmation message
        severity = state["severity"].strip().lower()
        if severity in ["low", "medium"]:
            print(f"\nVerification was approved by human, Email sent to {receiver_email} successfully")
        else:
            print("\nEmail sent successfully for high severity alert")

        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Successfully sent weather alert email for {state['city']}")],
            "alerts": state["alerts"] + [f"Email alert sent: {datetime.now()}"]
        }

    except Exception as e:
        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to send email alert: {str(e)}")]
        }

# %% [markdown]
# (k) Handling No Approval

# %%
def handle_no_approval(state: WeatherState) -> WeatherState:
    """Handle cases where human verification was rejected"""
    print("\nVerification was not approved by human, Email not sent")

    message = (
        f"Alert not sent for {state['city']} - "
        f"Weather severity level '{state['severity']}' was deemed non-critical "
        f"by human operator and verification was rejected."
    )
    return {
        **state,
        "messages": state["messages"] + [SystemMessage(content=message)]
    }

# %% [markdown]
# (l) Routing the Response

# %%
def route_response(state: WeatherState) -> Literal["emergency_response", "send_email_alert", "civil_defense_response", "public_works_response"]:
    """Route to appropriate department based on disaster type and severity"""
    disaster = state["disaster_type"].strip().lower()
    severity = state["severity"].strip().lower()

    if severity in ["critical", "high"]:
        return "emergency_response"
        "send_email_alert"
    elif "flood" in disaster or "storm" in disaster:
        return "public_works_response"
    else:
        return "civil_defense_response"

# %% [markdown]
# (m) Approval Verification Router

# %%
def verify_approval_router(state: WeatherState) -> Literal["send_email_alert", "handle_no_approval"]:
    """Route based on human approval decision"""
    return "send_email_alert" if state['human_approved'] else "handle_no_approval"

# %% [markdown]
# (n) Formatting the Weather Email

# %%
def format_weather_email(state: WeatherState) -> str:
    """Format weather data and severity assessment into an email message"""
    weather_data = state["weather_data"]

    email_content = f"""
Weather Alert for {state['city']}

Disaster Type: {state['disaster_type']}
Severity Level: {state['severity']}

Current Weather Conditions:
- Weather Description: {weather_data['weather']}
- Temperature: {weather_data['temperature']}C
- Wind Speed: {weather_data['wind_speed']} m/s
- Humidity: {weather_data['humidity']}%
- Pressure: {weather_data['pressure']} hPa
- Cloud Cover: {weather_data['cloud_cover']}%

Response Plan:
{state['response']}

This is an automated weather alert generated at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
"""

    if state['severity'].lower() in ['low', 'medium']:
        email_content += "\nNote: This low/medium severity alert has been verified by a human operator."

    return email_content

# %% [markdown]
# 5. Creating and Compiling the Workflow

# %%
# Create the workflow
workflow = StateGraph(WeatherState)

# Add nodes
workflow.add_node("get_weather", get_weather_data)
workflow.add_node("analyze_disaster", analyze_disaster_type)
workflow.add_node("assess_severity", assess_severity)
workflow.add_node("data_logging", data_logging)
workflow.add_node("emergency_response", emergency_response)
workflow.add_node("civil_defense_response", civil_defense_response)
workflow.add_node("public_works_response", public_works_response)
workflow.add_node("get_human_verification", get_human_verification)
workflow.add_node("send_email_alert", send_email_alert)
workflow.add_node("handle_no_approval", handle_no_approval)

# Add edges
workflow.add_edge("get_weather","analyze_disaster" )
workflow.add_edge("analyze_disaster", "assess_severity")
workflow.add_edge("assess_severity", "data_logging")
workflow.add_conditional_edges("data_logging", route_response)
workflow.add_edge("civil_defense_response", "get_human_verification")
workflow.add_edge("public_works_response", "get_human_verification")
workflow.add_conditional_edges("get_human_verification", verify_approval_router)
workflow.add_edge("emergency_response", "send_email_alert")
workflow.add_edge("send_email_alert", END)
workflow.add_edge("handle_no_approval", END)

workflow.set_entry_point("get_weather")

# Compile the workflow
app = workflow.compile()

# %% [markdown]
# 6 Running the Weather Emergency System

# %% [markdown]
# (a) run_weather_emergency_system(city: str)

# %%
def run_weather_emergency_system(city: str):
    """Initialize and run the weather emergency system for a given city"""
    initial_state = {
        "city": city,
        "weather_data": {},
        "disaster_type": "",
        "severity": "",
        "response": "",
        "messages": [],
        "alerts": [],
        "social_media_reports": [],
        "human_approved": False
    }

    try:
        result = app.invoke(initial_state)
        print(f"Completed weather check for {city}")
        return result
    except Exception as e:
        print(f"Error running weather emergency system: {str(e)}")

# %% [markdown]
# (b) Main Function of the Weather Emergency Response System

# %%
def main():
    """Main function to run the weather emergency system"""
    # Set up environment variables
    os.environ["SENDER_EMAIL"] = "asif.ml.developer@gmail.com"  # Your email (don't change this please)
    os.environ["RECEIVER_EMAIL"] = "noor31fat10@gmail.com"  # Recipient email (you can give your email here to check)
    os.environ["EMAIL_PASSWORD"] = "iulr lsdb glfy pfbs"  # app password(don't change this please)

    def scheduled_check():
        """Function to perform scheduled checks for multiple cities"""
        cities = ['London', 'karachi']  # Add more cities as needed
        print(f"\nStarting scheduled check at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

        for city in cities:
            try:
                print(f"\nChecking weather conditions for {city}...")
                run_weather_emergency_system(city)
                time.sleep(2)  # Brief pause between cities
            except Exception as e:
                print(f"Error checking {city}: {str(e)}")

    # Schedule checks every hour
    schedule.every(1).minute.do(scheduled_check)
    print("Weather Emergency Response System started.")
    print("Monitoring scheduled for every minute.")

    while True:
        try:
            schedule.run_pending()
            time.sleep(1)
        except KeyboardInterrupt:
            print("\nShutting down Weather Emergency Response System...")
            break
        except Exception as e:
            print(f"Error in main loop: {str(e)}")
            time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Weather Emergency Response System started.
# Monitoring scheduled for every minute.
#
# Starting scheduled check at 2025-07-13 13:12:00
#
# Checking weather conditions for London...
#
# ==================================================
# Low/Medium severity alert for London requires human approval:
# Disaster Type: No Immediate Threat
# Current Weather: clear sky
# Temperature: 19.6°C
# Wind Speed: 1.99 m/s
# Severity: Low
# Response Plan: ## London Civil Defence Response Plan: No Immediate Threat - Low Severity
#
# **Incident Type:** No Immediate Threat (e.g., minor chemical spill contained, localized power outage, small-scale flooding with minimal impact)
#
# **Severity Level:** Low
#
# **Date:** October 26, 2023
#
# **1.0 Purpose:** This plan outlines the response procedures for public safety in London during a low-severity, no-immediate-threat incident.  The focus is on minimizing disruption and ensuring public safety through proactive communication and coordinated actions.
#
# **2.0 Activation:** This plan is activated by the London Emergency Response Coordination Centre (LERCC) based on information received from various sources (e.g., emergency services, local authorities, public reports).
#
# **3.0 Response Objectives:**
#
# * Protect public safety and minimize disruption.
# * Provide accurate and timely information to the public.
# * Coordinate actions between relevant agencies.
# * Restore normal services as quickly and safely as possible.
#
#
# **4.0 Response Actions:**
#
# **4.1 Communication:**
#
# * **Public Information:** LERCC will utilize existing communication channels (website, social media, emergency alert system – only if necessary) to inform the public about the situation, its impact, and recommended actions (e.g., avoiding a specific area, following traffic diversions).  Messages will be clear, concise, and regularly updated.
# * **Media Liaison:** A dedicated media team will manage communication with the press, providing accurate and consistent information.
# * **Internal Communication:**  Clear communication channels will be maintained between LERCC, emergency services, local authorities, and other relevant agencies.
#
#
# **4.2 Public Safety Measures:**
#
# * **Traffic Management:**  If necessary, the Metropolitan Police will manage traffic flow around the affected area, implementing diversions and closures as required.
# * **Crowd Control:**  If necessary, the Metropolitan Police will manage crowds to prevent congestion and ensure public safety.
# * **Emergency Services Deployment:**  Emergency services will be deployed as needed to provide first aid, manage the incident, and support other agencies.  Deployment will be proportionate to the threat level.
# * **Public Assistance:**  Local authorities will provide assistance to vulnerable individuals (elderly, disabled) affected by the incident.
# * **Environmental Monitoring:** Relevant agencies (e.g., Environment Agency) will monitor environmental conditions to ensure public safety.
#
#
# **4.3 Agency Coordination:**
#
# * LERCC will act as the central coordination point for all agencies involved.
# * Regular meetings will be held to assess the situation and coordinate actions.
# * Information sharing will be facilitated through established communication channels.
#
#
# **5.0 Demobilization:**
#
# This plan will be demobilized when the LERCC determines that the incident is fully resolved, public safety is ensured, and normal services are restored. A post-incident review will be conducted to identify lessons learned and improve future responses.
#
#
# **6.0 Roles and Responsibilities:**
#
# * **LERCC:** Overall coordination and management of the response.
# * **Metropolitan Police:** Public safety, traffic management, crowd control.
# * **London Ambulance Service:** Medical assistance and emergency response.
# * **London Fire Brigade:** Fire safety and emergency response.
# * **Local Authorities:** Public assistance, community engagement, environmental monitoring (where applicable).
# * **Transport for London:** Public transport management and information.
#
#
# **7.0 Annexes:**
#
# * Contact list of key personnel.
# * Communication protocols.
# * Maps of affected areas (as applicable).
#
#
# **Note:** This is a template plan and needs to be adapted to the specific circumstances of each incident. The level of response will be scaled appropriately based on the evolving situation.  Regular training and exercises will ensure that all agencies are prepared to respond effectively.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Please enter 'y' for yes or 'n' for no:
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for London
#
# Checking weather conditions for karachi...
#
# ==================================================
# Low/Medium severity alert for karachi requires human approval:
# Disaster Type: No Immediate Threat
#
# While the temperature is quite high (31.6°C), the other conditions don't indicate an imminent severe weather disaster.  The wind speed is moderate, the pressure is relatively normal, and while the humidity is somewhat high, it's not exceptionally so. Overcast clouds are common and don't automatically signal a disaster.  None of the conditions suggest a hurricane, flood, severe storm, or winter storm.  A heatwave is possible with the high temperature, but without more context (like prolonged duration of these conditions and heat index) it's not definitively a heatwave *disaster*.
# Current Weather: overcast clouds
# Temperature: 31.6°C
# Wind Speed: 7.58 m/s
# Severity: Low
# Response Plan: ## Public Works Response Plan: No Immediate Threat - Karachi (High Temperature)
#
# **Incident:** High temperature (31.6°C), moderate wind, normal pressure, somewhat high humidity, overcast skies.  No immediate threat of severe weather disaster.
#
# **Severity Level:** Low
#
# **Date:** October 26, 2023 (Example Date)
#
# **Objective:** Proactive infrastructure protection measures in anticipation of potential heat-related issues.
#
# **I. Situation Assessment:**
#
# * Current weather conditions:  31.6°C, moderate wind, normal pressure, moderately high humidity, overcast skies.  No immediate threat of severe weather.
# * Potential risks:  Prolonged high temperatures could lead to increased stress on infrastructure (e.g., expansion of roads, increased water demand).  Heat-related issues for the public are a concern, but not directly a Public Works responsibility.
# * Infrastructure vulnerabilities:  Roads, bridges, and water infrastructure are the primary concerns in high temperatures.
#
# **II. Response Actions:**
#
# **A. Monitoring and Surveillance:**
#
# * **Continuous monitoring:** Public Works personnel will continue monitoring weather forecasts for any changes in conditions that might escalate the threat level.
# * **Infrastructure inspection:** Routine inspections of critical infrastructure (roads, bridges, water supply systems, drainage systems) will be conducted to identify any existing vulnerabilities or early signs of heat stress.  Focus on areas with known past issues.
# * **Data collection:**  Temperature readings at various locations will be collected and recorded.
#
# **B. Proactive Measures:**
#
# * **Water management:**  Ensure sufficient water pressure and flow in the water distribution system.  Check for leaks and address them promptly.
# * **Road maintenance:**  Focus on preventative maintenance to address any existing cracks or issues that could worsen with expansion and contraction due to temperature fluctuations.  Prioritize areas with known issues or heavy traffic.
# * **Drainage system check:**  Inspect drainage systems for blockages to ensure efficient water flow and prevent waterlogging.
# * **Communication:**  Internal communication among Public Works teams will be maintained to ensure coordinated response.
#
# **C. Contingency Planning:**
#
# * **Heatwave preparedness:**  While not currently a crisis, develop a preliminary plan for a potential heatwave, focusing on infrastructure protection (e.g., strategies for addressing potential road buckling). This plan should include communication protocols with relevant agencies (health department, emergency services).
# * **Resource allocation:**  Identify and pre-position necessary resources (equipment, personnel) for potential future needs.
#
# **III. Communication:**
#
# * Internal communication: Regular updates and briefings to all Public Works personnel.
# * External communication:  No public announcement is necessary at this time.  Information will be shared with relevant agencies as needed.
#
# **IV. Reporting:**
#
# * Daily reports will be generated summarizing weather conditions, infrastructure inspections, and any actions taken.
# * Any significant changes in the situation will be immediately reported to the appropriate authorities.
#
# **V. Review and Evaluation:**
#
# * This plan will be reviewed and updated as needed based on the evolving weather conditions and any lessons learned.
#
# **VI.  Escalation:**
#
# * If the weather conditions worsen significantly, or if any infrastructure damage occurs, the severity level will be upgraded, and a more comprehensive response plan will be activated.
#
#
# This plan focuses solely on infrastructure protection.  Collaboration with other agencies (health, emergency services) will be vital if the situation escalates to a heatwave impacting the public.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for karachi
#
# Starting scheduled check at 2025-07-13 13:16:05
#
# Checking weather conditions for London...
#
# ==================================================
# Low/Medium severity alert for London requires human approval:
# Disaster Type: No Immediate Threat
# Current Weather: clear sky
# Temperature: 19.6°C
# Wind Speed: 1.99 m/s
# Severity: Low
# Response Plan: ## London Civil Defence Response Plan: No Immediate Threat - Low Severity
#
# **Incident Type:** No Immediate Threat (e.g., minor technological malfunction, localized power outage affecting a small area, controlled hazardous material spill with minimal risk of spread)
#
# **Severity Level:** Low
#
# **Date:** October 26, 2023
#
# **1.0 Objectives:**
#
# * Ensure public safety and minimize disruption.
# * Provide accurate and timely information to the public.
# * Coordinate response efforts effectively between agencies.
# * Restore normalcy as quickly and efficiently as possible.
#
#
# **2.0 Activation Criteria:**
#
# This plan is activated when an incident is classified as a "No Immediate Threat" and assessed as Low Severity by the London Emergency Response Coordination Centre (LERCC) or equivalent authority.  Criteria include:
#
# * Limited geographical impact.
# * Minimal risk to life or serious injury.
# * Containment measures are in place or readily implementable.
# * No significant disruption to essential services (transport, utilities, communication).
#
#
# **3.0 Response Procedures:**
#
# **3.1 Information Management:**
#
# * **LERCC:** Acts as the central coordinating point, disseminating information to relevant agencies and the public through official channels (website, social media, press releases).  Information will be factual, concise, and avoid causing unnecessary alarm.
# * **Public Information:**  Simple, clear messages will be disseminated via:
#     *  London Councils' websites and social media.
#     *  Local radio and television broadcasts.
#     *  Emergency alert systems (where appropriate).
# * **Media Liaison:** Designated spokesperson will manage communication with the media, providing regular updates and answering questions accurately.
#
#
# **3.2 Public Safety Measures:**
#
# * **Perimeter Control (if necessary):**  Local authorities will implement minimal perimeter control to ensure public safety and facilitate response efforts.  This might involve temporary road closures or diversions.
# * **Emergency Services:**  London Ambulance Service, London Fire Brigade, and Metropolitan Police will respond as necessary, based on the specific incident.  Their deployment will be coordinated by LERCC.
# * **Public Advice:**  Public announcements will advise citizens on precautionary measures, such as staying indoors if advised, avoiding specific areas, or following alternative routes.
# * **Vulnerable Populations:**  Special attention will be paid to the needs of vulnerable populations (elderly, disabled, etc.), with proactive outreach and support provided as needed.
#
#
# **3.3 Resource Allocation:**
#
# * LERCC will oversee resource allocation, ensuring that appropriate personnel and equipment are deployed effectively.
# * Local authorities will provide support as needed, including personnel, equipment, and logistical assistance.
#
#
# **4.0 Monitoring and Evaluation:**
#
# * LERCC will continuously monitor the situation and adjust the response as necessary.
# * Post-incident review will be conducted to identify areas for improvement in future responses.
#
#
# **5.0 Communication Channels:**
#
# * LERCC: [Contact details]
# * Local Authorities: [Contact details]
# * Emergency Services: [Contact details]
#
#
# **6.0 Annexes:**
#
# * List of key personnel and contact information.
# * Maps of affected areas.
# * Detailed procedures for specific incident types (e.g., power outage, hazardous material spill).
#
#
# **Note:** This is a template and should be adapted based on the specific nature of the incident and available resources.  Regular training and exercises are crucial to ensure the effectiveness of this plan.  This plan will be reviewed and updated annually or as needed.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for London
#
# Checking weather conditions for karachi...
#
# ==================================================
# Low/Medium severity alert for karachi requires human approval:
# Disaster Type: No Immediate Threat
#
# While the temperature is high (31.6°C), the other conditions don't indicate an imminent weather disaster.  The wind speed is moderate, the pressure is relatively normal, and the humidity, while somewhat high, isn't exceptionally so. Overcast clouds can lead to rain, but there's no indication of heavy rainfall or other severe weather phenomena.
# Current Weather: overcast clouds
# Temperature: 31.6°C
# Wind Speed: 7.58 m/s
# Severity: Low
# Response Plan: ## Civil Defense Response Plan: Karachi - No Immediate Threat (High Temperature)
#
# **Date:** October 26, 2023
# **Situation:** High temperature (31.6°C), overcast conditions, moderate wind, normal pressure, moderate humidity.  No immediate threat of severe weather. Severity Level: Low.
#
# **Objective:** To ensure public safety and minimize the impact of the high temperature and potential for later rainfall.
#
# **I.  Assessment & Monitoring:**
#
# * **Meteorological Monitoring:** Continue monitoring weather forecasts from reliable sources (e.g., Pakistan Meteorological Department) for any changes in the weather pattern. Pay close attention to potential shifts towards heavy rainfall or thunderstorms.
# * **Heat Stress Monitoring:**  Monitor heat-related illnesses reported to emergency services.  This data will inform resource allocation.
#
# **II. Public Safety Measures:**
#
# * **Public Awareness Campaign:** Disseminate information through various channels (radio, television, SMS alerts, social media) urging citizens to:
#     * **Stay Hydrated:** Drink plenty of water throughout the day, even if not feeling thirsty. Avoid sugary drinks.
#     * **Seek Shade:** Limit exposure to direct sunlight, especially during peak hours.
#     * **Wear Light Clothing:** Wear loose-fitting, light-colored clothing.
#     * **Check on Vulnerable Populations:**  Encourage individuals to check on elderly relatives, neighbors, and those with pre-existing health conditions.
#     * **Heatstroke Awareness:**  Provide information on recognizing and responding to heatstroke symptoms (high body temperature, rapid pulse, dizziness, confusion).
#     * **Potential for Rainfall:**  Inform the public about the possibility of rain and advise them to take precautions, such as securing loose objects and avoiding flooded areas.
#
# * **Emergency Services Readiness:**
#     * Ensure adequate staffing levels for emergency medical services (EMS) and hospitals to handle potential heat-related illnesses.
#     * Prepare cooling centers in designated public buildings (schools, community centers) with adequate water and ventilation.  Publicize the locations of these centers.
#     * Ensure ambulances are adequately stocked with supplies for treating heatstroke.
#
# * **Infrastructure Checks:**
#     * Check drainage systems to ensure they are clear to handle potential rainfall.
#     * Monitor for any potential hazards that could be exacerbated by high temperatures (e.g., risk of fire).
#
# **III. Resource Allocation:**
#
# * **Water Distribution:**  Ensure adequate supplies of potable water are available, especially in vulnerable areas.
# * **Medical Supplies:**  Maintain sufficient stocks of medication and supplies needed to treat heat-related illnesses.
# * **Communication Systems:**  Ensure reliable communication channels are functioning effectively.
#
# **IV. Reporting & Evaluation:**
#
# * Establish a reporting system for heat-related incidents and weather updates.
# * Regularly review the situation and adjust the response plan as needed based on weather updates and incident reports.
# * Conduct a post-event evaluation to identify areas for improvement in future response plans.
#
#
# **V. Escalation Procedures:**
#
# If the weather forecast deteriorates and indicates a significant threat (e.g., heavy rainfall, thunderstorms, strong winds), immediately escalate the response to a higher level, activating more extensive emergency measures as outlined in the city's severe weather response plan.
#
#
# This plan is a guideline and should be adapted to the specific needs and circumstances of Karachi.  Regular updates and training are crucial to ensure effective implementation.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for karachi
#
# Starting scheduled check at 2025-07-13 13:21:51
#
# Checking weather conditions for London...
#
# ==================================================
# Low/Medium severity alert for London requires human approval:
# Disaster Type: No Immediate Threat
# Current Weather: clear sky
# Temperature: 19.6°C
# Wind Speed: 1.99 m/s
# Severity: Low
# Response Plan: ## London Civil Defence Response Plan: No Immediate Threat, Low Severity Situation
#
# **Situation:** A low-severity incident affecting public safety has occurred in London, posing no immediate threat of widespread harm or significant infrastructure damage. This could include, but is not limited to:  localized power outage, minor chemical spill with contained impact, localized flooding, or a minor traffic incident causing significant congestion.
#
# **Severity Level:** Low
#
# **Threat Level:** No Immediate Threat
#
# **I. Objectives:**
#
# * To ensure public safety and minimize disruption.
# * To provide accurate and timely information to the public.
# * To coordinate the response of relevant agencies.
# * To facilitate a swift return to normalcy.
#
# **II. Response Teams & Responsibilities:**
#
# * **London Resilience Partnership (LRP):** Overall coordination and strategic direction.
# * **Metropolitan Police Service (MPS):** Traffic management, crowd control, crime prevention, scene security (if applicable).
# * **London Fire Brigade (LFB):** Hazardous material response (if applicable), fire safety, rescue operations (if applicable).
# * **London Ambulance Service (LAS):** Medical response, casualty evacuation (if applicable).
# * **Transport for London (TfL):** Public transport management, disruption information.
# * **Local Authorities:**  Support to affected communities, provision of temporary accommodation/facilities (if applicable).
# * **National Grid/Utility Companies:** Restoration of essential services (power, water, gas).
# * **Public Health England (PHE):** Public health advice and monitoring (if applicable).
#
#
# **III. Public Safety Measures:**
#
# * **Information Dissemination:**
#     * Utilize official channels (TfL website, social media, local authority websites, emergency alerts) to provide accurate, concise, and timely updates to the public.
#     * Avoid speculation and misinformation.
#     * Provide clear instructions on how to stay safe and what actions to take (e.g., avoid affected areas, follow diversions).
# * **Traffic Management:**
#     * MPS and TfL will implement traffic diversions and manage congestion to ensure safe passage and emergency vehicle access.
#     * Public transport services will be adjusted as needed.
# * **Community Engagement:**
#     * Local authorities will communicate with residents in affected areas, providing support and information.
#     * Community leaders and volunteers may be mobilized to assist with information dissemination and support.
# * **Emergency Shelters:**
#     * Local authorities will identify and prepare temporary shelters if needed (e.g., community centers, schools).
# * **Resource Allocation:**
#     * LRP will coordinate the allocation of resources (personnel, equipment, supplies) to ensure efficient response.
# * **Incident Monitoring & Evaluation:**
#     * Continuous monitoring of the situation to assess the effectiveness of the response and identify any emerging issues.
#     * Post-incident review to identify areas for improvement.
#
#
# **IV. Communication Protocol:**
#
# * A dedicated communication hub will be established, using secure channels to facilitate information sharing between agencies.
# * Regular briefings will be held to update stakeholders on the situation and response efforts.
# * A designated spokesperson will communicate with the media and public.
#
#
# **V. De-escalation & Recovery:**
#
# * Once the immediate threat has passed, focus will shift to restoring normal services and supporting affected communities.
# * Damage assessment will be conducted and repair work initiated.
# * Psychological support will be offered to those affected, if necessary.
#
#
# **VI. Training & Exercises:**
#
# * Regular training and exercises involving all participating agencies are crucial to ensure preparedness and effective coordination.
#
#
# This plan is a framework and will need to be adapted based on the specifics of the incident.  The LRP will lead the activation and management of this plan, adapting it to the specific circumstances.  This plan prioritizes public safety and aims to minimize disruption while ensuring a swift return to normalcy.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for London
#
# Checking weather conditions for karachi...
#
# ==================================================
# Low/Medium severity alert for karachi requires human approval:
# Disaster Type: No Immediate Threat
#
# While the temperature is high (31.6°C), the other conditions don't indicate an imminent severe weather event like a hurricane, flood, severe storm, or winter storm.  The wind speed is moderate, the pressure is relatively normal, and the humidity, while somewhat high, isn't exceptionally so.  Overcast clouds are common and don't themselves signal a disaster.
# Current Weather: overcast clouds
# Temperature: 31.6°C
# Wind Speed: 7.58 m/s
# Severity: Low
# Response Plan: ## Public Works Response Plan: Karachi - High Temperature, No Immediate Threat (Low Severity)
#
# **Date:** October 26, 2023
# **Incident:** High Temperature (31.6°C), No Imminent Severe Weather Threat
# **Severity Level:** Low
# **Location:** Karachi
#
# **1. Situation Assessment:**
#
# Current conditions indicate a high temperature (31.6°C) in Karachi.  While uncomfortable, this temperature alone does not pose an immediate threat requiring a major emergency response.  Other meteorological factors (wind speed, pressure, humidity) are within normal ranges.  The focus of this plan is proactive infrastructure protection to mitigate potential long-term impacts of sustained high temperatures.
#
# **2. Objectives:**
#
# * Minimize potential damage to public infrastructure due to heat stress.
# * Ensure the continued functionality of critical infrastructure systems.
# * Proactively address potential vulnerabilities exacerbated by high temperatures.
#
# **3. Response Actions:**
#
# **A. Infrastructure Monitoring & Protection:**
#
# * **Roads:** Increased monitoring of asphalt expansion and potential cracking.  Focus on areas with known vulnerabilities.  Minor cracking will be documented and scheduled for repair during cooler periods.
# * **Bridges & Overpasses:** Inspection for expansion joint issues and potential structural stress caused by heat.  Report any abnormalities to the structural engineering department.
# * **Water Supply System:**  Increased monitoring of water pressure and flow rates to detect leaks potentially exacerbated by ground expansion.  Proactive leak detection and repair will be prioritized.
# * **Sewer System:**  Monitoring for increased flow due to higher water usage and potential for ground subsidence.  Prioritize clearing of blockages to maintain efficient drainage.
# * **Power Grid:**  Increased vigilance for potential overheating of transformers and other electrical equipment.  Coordination with the electricity provider for preventative maintenance and monitoring.
# * **Public Parks & Green Spaces:**  Increased watering schedules for trees and vegetation to mitigate heat stress.  Ensure irrigation systems are functioning optimally.
#
# **B. Communication & Coordination:**
#
# * Internal communication within the Public Works Department to ensure all teams are aware of the plan and their responsibilities.
# * Coordination with the Karachi Meteorological Department for updated weather forecasts.
# * Public information dissemination (if necessary) regarding heat safety tips, especially for vulnerable populations, through existing communication channels.
#
# **4. Resource Allocation:**
#
# * Dedicated teams for monitoring and inspection of critical infrastructure.
# * Necessary equipment for repairs and maintenance (e.g., asphalt patching materials, leak detection tools).
# * Access to emergency contact numbers for relevant agencies (e.g., electricity provider, water department).
#
# **5. Contingency Planning:**
#
# If the temperature significantly increases or other weather conditions change, this plan will be reviewed and updated to reflect the evolving situation.  A higher-level emergency response plan will be activated if the severity level increases.
#
#
# **6. Post-Incident Review:**
#
# A post-incident review will be conducted to assess the effectiveness of the response plan and identify areas for improvement.  This review will include documenting any infrastructure damage or issues encountered and adjusting preventative measures for future high-temperature events.
#
#
# **7.  Contact Information:**
#
# [Insert contact details for relevant Public Works Department personnel and emergency services]
#
#
# This plan serves as a guideline and may be modified based on the evolving situation and available resources.  The primary focus remains on proactive infrastructure protection to mitigate potential long-term impacts of sustained high temperatures.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Human verification result: Approved
#
# Verification was approved by human, Email sent to noor31fat10@gmail.com successfully
# Completed weather check for karachi
#
# Starting scheduled check at 2025-07-13 13:23:32
#
# Checking weather conditions for London...
#
# ==================================================
# Low/Medium severity alert for London requires human approval:
# Disaster Type: No Immediate Threat
# Current Weather: clear sky
# Temperature: 19.6°C
# Wind Speed: 1.99 m/s
# Severity: Low
# Response Plan: ## London Civil Defence Response Plan: No Immediate Threat - Low Severity
#
# **Incident Type:** No Immediate Threat (e.g., minor chemical spill contained, isolated power outage affecting a small area, localized flooding with minimal impact)
#
# **Severity Level:** Low
#
# **Date:** October 26, 2023
#
# **1.0 Purpose:** This plan outlines the public safety response for low-severity incidents in London posing no immediate threat to life or widespread infrastructure. The focus is on mitigating impacts, providing information, and restoring normalcy.
#
# **2.0 Activation Criteria:** This plan is activated when an incident is assessed as posing a low severity, no immediate threat situation by the London Resilience Team (LRT) or designated authority.  Criteria include:
#
# * Limited geographical impact.
# * No injuries or fatalities anticipated.
# * Minimal disruption to essential services.
# * Contained incident with no ongoing risk of escalation.
#
# **3.0 Response Structure:**
#
# * **Incident Commander:** Designated LRT representative.
# * **Public Information Officer (PIO):** Responsible for communication with the public.
# * **Emergency Services Liaison:** Coordinates with London Ambulance Service (LAS), London Fire Brigade (LFB), Metropolitan Police Service (MPS), etc.
# * **Council Liaison:**  Coordinates with relevant borough councils for local actions.
# * **Utilities Liaison:** Coordinates with utility providers (electricity, gas, water) as needed.
#
#
# **4.0 Public Safety Measures:**
#
# * **Information Dissemination:**
#     * The PIO will utilize official channels (London Councils website, social media, local radio/TV) to inform the public about the incident, its impact, and any necessary precautions.
#     * Clear, concise, and accurate information will be provided, avoiding speculation or alarmist language.
#     * Updates will be issued regularly.
#     * Translation services will be provided as necessary.
# * **Crowd Management:**  If necessary, MPS will manage crowds to ensure public safety and avoid obstruction of emergency services.
# * **Evacuation (if necessary):**  If a limited evacuation is required, clear instructions and designated safe zones will be provided.  Support for vulnerable individuals will be prioritized.
# * **Shelter Provision (if necessary):**  If needed, temporary shelter will be provided in collaboration with borough councils and voluntary organizations.
# * **Public Health:**  If relevant, Public Health England (PHE) will provide guidance on health risks and preventative measures.
# * **Traffic Management:** MPS and Transport for London (TfL) will manage traffic to minimize disruption and ensure emergency vehicle access.
# * **Waste Management:**  If the incident involves hazardous materials, appropriate waste management procedures will be followed by specialized teams.
#
# **5.0 Communication Plan:**
#
# * **Internal Communication:**  Regular updates and briefings will be provided to all response personnel.
# * **External Communication:**  Consistent messaging across all channels to avoid confusion and maintain public trust.  Social media monitoring will be undertaken to address public concerns and misinformation.
#
# **6.0 Monitoring and Evaluation:**
#
# * The LRT will monitor the situation continuously.
# * Post-incident review will be conducted to identify areas for improvement in the response plan.
#
# **7.0 De-escalation and Recovery:**
#
# * Once the incident is resolved and the threat is eliminated, the PIO will inform the public.
# * Recovery efforts will focus on restoring normal services and addressing any remaining impacts.
#
# **8.0 Annexes:**
#
# * Contact list of key personnel
# * Map of affected area (if applicable)
# * Communication protocols
# * Emergency procedures for specific incident types (e.g., power outage, minor chemical spill)
#
#
# **Note:** This plan is a template and needs to be adapted based on the specific characteristics of the actual incident.  The severity level could be upgraded if the situation changes.  Regular training and exercises are crucial for effective implementation.
#
# Type 'y' to approve sending alert or 'n' to reject (waiting for input):
# ==================================================
# Please enter 'y' for yes or 'n' for no:
# Please enter 'y' for yes or 'n' for no:
# Please enter 'y' for yes or 'n' for no:
#
# Shutting down Weather Emergency Response System...

# %% [markdown]
# 7. Visualize the Graph

# %%
from IPython.display import Image, display

try:
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %% [markdown]
# Part 2

# %% [markdown]
# Hybrid Agent Graph (Simulate High Severity Weather level check with dummy weather and Social Monitoring data):
# Note: Below, only details are given for nodes or functions, which are not described above

# %%
import os
import random
import requests
import schedule
import time
from typing import Dict, TypedDict, Union, List, Literal
import json
from datetime import datetime
from langgraph.graph import StateGraph, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %% [markdown]
# Defining an LLM and a State Class

# %%
# Initialize LLM
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

class WeatherState(TypedDict):
    city: str
    weather_data: Dict
    disaster_type: str
    severity: str
    response: str
    messages: List[Union[SystemMessage, HumanMessage, AIMessage]]
    alerts: List[str]
    social_media_reports: List[str]
    human_approved: bool

# %% [markdown]
# Define Node Functions
# (a) Fetching Weather Data

# %%
def get_weather_data(state: WeatherState) -> Dict:
    """Fetch weather data from OpenWeatherMap API or use simulated data in test mode"""
    # Check if we're in test mode (indicated by pre-populated weather_data)
    if state['weather_data']:
        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Using simulated weather data for {state['city']}")]
        }

    # If not in test mode, fetch real data from API
    BASE_URL = "http://api.openweathermap.org/data/2.5/weather"
    API_KEY = os.getenv("API_KEY")

    request_url = f"{BASE_URL}?appid={API_KEY}&q={state['city']}"
    try:
        response = requests.get(request_url)
        response.raise_for_status()

        data = response.json()
        weather_data = {
            "weather": data.get('weather', [{}])[0].get("description", "N/A"),
            "wind_speed": data.get("wind", {}).get("speed", "N/A"),
            "cloud_cover": data.get("clouds", {}).get("all", "N/A"),
            "sea_level": data.get("main", {}).get("sea_level", "N/A"),
            "temperature": round(data.get("main", {}).get("temp", 273.15) - 273.15, 1),
            "humidity": data.get("main", {}).get("humidity", "N/A"),
            "pressure": data.get("main", {}).get("pressure", "N/A")
        }

        return {
            **state,
            "weather_data": weather_data,
            "messages": state["messages"] + [SystemMessage(content=f"Weather data fetched successfully for {state['city']}")]
        }
    except Exception as e:
        error_data = {
            "weather": "N/A",
            "wind_speed": "N/A",
            "cloud_cover": "N/A",
            "sea_level": "N/A",
            "temperature": "N/A",
            "humidity": "N/A",
            "pressure": "N/A"
        }
        return {
            **state,
            "weather_data": error_data,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to fetch weather data for {state['city']}: {str(e)}")]
        }

# %% [markdown]
# (b) Social Media Monitoring

# %%
def social_media_monitoring(state: WeatherState) -> WeatherState:
    """Simulate monitoring social media for additional reports of the weather event."""
    simulated_reports = [
        "Local reports of rising water levels and minor flooding.",
        "High winds causing power outages in parts of the city.",
        "Citizens reporting high temperatures and increased heat discomfort.",
        "Social media reports indicate severe storm damage in local infrastructure.",
        "Reports of traffic disruptions due to heavy rain.",
        "No unusual social media reports related to the weather at this time."
    ]

    social_media_report = random.choice(simulated_reports)
    return {
        **state,
        "social_media_reports": state["social_media_reports"] + [social_media_report],
        "messages": state["messages"] + [SystemMessage(content=f"Social media report added: {social_media_report}")]
    }

# %% [markdown]
# (c) Analyzing Disaster Type

# %%
def analyze_disaster_type(state: WeatherState) -> WeatherState:
    """Analyze weather data to identify potential disasters"""
    weather_data = state["weather_data"]
    prompt = ChatPromptTemplate.from_template(
        "Based on the following weather conditions, identify if there's a potential weather disaster.\n"
        "Weather conditions:\n"
        "- Description: {weather}\n"
        "- Wind Speed: {wind_speed} m/s\n"
        "- Temperature: {temperature}°C\n"
        "- Humidity: {humidity}%\n"
        "- Pressure: {pressure} hPa\n"
        "Categorize into one of these types: Hurricane, Flood, Heatwave, Severe Storm, Winter Storm, or No Immediate Threat"
    )

    try:
        chain = prompt | llm
        disaster_type = chain.invoke(weather_data).content
        return {
            **state,
            "disaster_type": disaster_type,
            "messages": state["messages"] + [SystemMessage(content=f"Disaster type identified: {disaster_type}")]
        }
    except Exception as e:
        return {
            **state,
            "disaster_type": "Analysis Failed",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to analyze disaster type: {str(e)}")]
        }

# %% [markdown]
# (d) Assess Severity Level

# %%
def assess_severity(state: WeatherState) -> WeatherState:
    """Assess the severity of the identified weather situation"""
    weather_data = state["weather_data"]
    prompt = ChatPromptTemplate.from_template(
        "Given the weather conditions and identified disaster type '{disaster_type}', "
        "assess the severity level. Consider:\n"
        "- Weather: {weather}\n"
        "- Wind Speed: {wind_speed} m/s\n"
        "- Temperature: {temperature}°C\n"
        "Respond with either 'Critical', 'High', 'Medium', or 'Low'"
    )

    try:
        chain = prompt | llm
        severity = chain.invoke({
            **weather_data,
            "disaster_type": state["disaster_type"]
        }).content

        return {
            **state,
            "severity": severity,
            "messages": state["messages"] + [SystemMessage(content=f"Severity assessed as: {severity}")]
        }
    except Exception as e:
        return {
            **state,
            "severity": "Assessment Failed",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to assess severity: {str(e)}")]
        }

# %% [markdown]
# (e) Emergency Response

# %%
def emergency_response(state: WeatherState) -> WeatherState:
    """Generate emergency response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create an emergency response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Include immediate actions needed."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Emergency response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate emergency response: {str(e)}")]
        }

# %% [markdown]
# (f) Civil Defense Response

# %%
def civil_defense_response(state: WeatherState) -> WeatherState:
    """Generate civil defense response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create a civil defense response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Focus on public safety measures."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Civil defense response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate civil defense response: {str(e)}")]
        }

# %% [markdown]
# (g) Public Works Response

# %%
def public_works_response(state: WeatherState) -> WeatherState:
    """Generate public works response plan"""
    prompt = ChatPromptTemplate.from_template(
        "Create a public works response plan for a {disaster_type} situation "
        "with {severity} severity level in {city}. Focus on infrastructure protection."
    )
    try:
        chain = prompt | llm
        response = chain.invoke({
            "disaster_type": state["disaster_type"],
            "severity": state["severity"],
            "city": state["city"]
        }).content

        return {
            **state,
            "response": response,
            "messages": state["messages"] + [SystemMessage(content="Public works response plan generated")]
        }
    except Exception as e:
        return {
            **state,
            "response": "Failed to generate response plan",
            "messages": state["messages"] + [SystemMessage(content=f"Failed to generate public works response: {str(e)}")]
        }

# %% [markdown]
# (h) Data Logging

# %%
def data_logging(state: WeatherState) -> WeatherState:
    """Log weather data, disaster analysis, and response to a file."""
    log_data = {
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "city": state["city"],
        "weather_data": state["weather_data"],
        "disaster_type": state["disaster_type"],
        "severity": state["severity"],
        "response": state["response"],
        "social_media_reports": state["social_media_reports"]
    }

    try:
        with open("disaster_log.txt", "a") as log_file:
            log_file.write(json.dumps(log_data) + "\n")

        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content="Data logged successfully")]
        }
    except Exception as e:
        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to log data: {str(e)}")]
        }

# %% [markdown]
# (j) Get Human Verification

# %%
def get_human_verification(state: WeatherState) -> WeatherState:
    """Get human verification for low/medium severity alerts"""
    severity = state["severity"].strip().lower()

    if severity in ["low", "medium"]:
        print("\n" + "="*50)
        print(f"Low/Medium severity alert for {state['city']} requires human approval:")
        print(f"Disaster Type: {state['disaster_type']}")
        print(f"Current Weather: {state['weather_data']['weather']}")
        print(f"Temperature: {state['weather_data']['temperature']}°C")
        print(f"Wind Speed: {state['weather_data']['wind_speed']} m/s")
        print(f"Severity: {state['severity']}")
        print(f"Response Plan: {state['response']}")
        print("\nType 'y' to approve sending alert or 'n' to reject (waiting for input):")
        print("="*50)

        # Block and wait for input
        while True:
            try:
                user_input = input().lower().strip()
                if user_input in ['y', 'n']:
                    approved = user_input == 'y'
                    print(f"Human verification result: {'Approved' if approved else 'Rejected'}")
                    break
                else:
                    print("Please enter 'y' for yes or 'n' for no:")
            except Exception as e:
                print(f"Error reading input: {str(e)}")
                print("Please try again with 'y' or 'n':")

        return {
            **state,
            "human_approved": approved,
            "messages": state["messages"] + [
                SystemMessage(content=f"Human verification: {'Approved' if approved else 'Rejected'}")
            ]
        }
    else:
        # Auto-approve for high/critical severity
        return {
            **state,
            "human_approved": True,
            "messages": state["messages"] + [
                SystemMessage(content=f"Auto-approved {severity} severity alert")
            ]
        }

# %% [markdown]
# (k) Send Email Alert

# %%
def send_email_alert(state: WeatherState) -> WeatherState:
    """Send weather alert email"""
    sender_email = os.getenv("SENDER_EMAIL")
    receiver_email = os.getenv("RECEIVER_EMAIL")
    password = os.getenv("EMAIL_PASSWORD")

    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = f"Weather Alert: {state['severity']} severity weather event in {state['city']}"

    body = format_weather_email(state)
    msg.attach(MIMEText(body, 'plain'))

    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, password)
        text = msg.as_string()
        server.sendmail(sender_email, receiver_email, text)
        server.quit()

        # Add confirmation message
        severity = state["severity"].strip().lower()
        if severity in ["low", "medium"]:
            print(f"\nVerification was approved by human, Email sent to {receiver_email} successfully")
        else:
            print(f"\nEmail sent successfully for high severity alert to {receiver_email}")

        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Successfully sent weather alert email for {state['city']}")],
            "alerts": state["alerts"] + [f"Email alert sent: {datetime.now()}"]
        }

    except Exception as e:
        return {
            **state,
            "messages": state["messages"] + [SystemMessage(content=f"Failed to send email alert: {str(e)}")]
        }

# %% [markdown]
# (l) Handle No Approval From Human

# %%
def handle_no_approval(state: WeatherState) -> WeatherState:
    """Handle cases where human verification was rejected"""
    print("\nVerification was not approved by human, Email not sent")

    message = (
        f"Alert not sent for {state['city']} - "
        f"Weather severity level '{state['severity']}' was deemed non-critical "
        f"by human operator and verification was rejected."
    )
    return {
        **state,
        "messages": state["messages"] + [SystemMessage(content=message)]
    }

# %% [markdown]
# (m) Route Response for Disaster Type and Severity

# %%
def route_response(state: WeatherState) -> Literal["emergency_response", "send_email_alert", "civil_defense_response", "public_works_response"]:
    """Route to appropriate department based on disaster type and severity"""
    disaster = state["disaster_type"].strip().lower()
    severity = state["severity"].strip().lower()

    if severity in ["critical", "high"]:
        return "emergency_response"
        return "send_email_alert"
    elif "flood" in disaster or "storm" in disaster:
        return "public_works_response"
    else:
        return "civil_defense_response"

# %% [markdown]
# (n) Verify Approval Route after Human Verification

# %%
def verify_approval_router(state: WeatherState) -> Literal["send_email_alert", "handle_no_approval"]:
    """Route based on human approval decision"""
    return "send_email_alert" if state['human_approved'] else "handle_no_approval"

# %% [markdown]
# (p) Format Weather Email

# %%
def format_weather_email(state: WeatherState) -> str:
    """Format weather data and severity assessment into an email message"""
    weather_data = state["weather_data"]
    social_media_reports = "\n".join(state["social_media_reports"])

    email_content = f"""
Weather Alert for {state['city']}

Disaster Type: {state['disaster_type']}
Severity Level: {state['severity']}

Current Weather Conditions:
- Weather Description: {weather_data['weather']}
- Temperature: {weather_data['temperature']}C
- Wind Speed: {weather_data['wind_speed']} m/s
- Humidity: {weather_data['humidity']}%
- Pressure: {weather_data['pressure']} hPa
- Cloud Cover: {weather_data['cloud_cover']}%


Response Plan:
{state['response']}

This is an automated weather alert generated at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
"""

    if state['severity'].lower() in ['low', 'medium']:
        email_content += "\nNote: This low/medium severity alert has been verified by a human operator."

    return email_content

# %% [markdown]
# Creating and Compiling the Workflow

# %%
# Create the workflow
workflow = StateGraph(WeatherState)

# Add nodes
workflow.add_node("get_weather", get_weather_data)
workflow.add_node("social_media_monitoring", social_media_monitoring)
workflow.add_node("analyze_disaster", analyze_disaster_type)
workflow.add_node("assess_severity", assess_severity)
workflow.add_node("data_logging", data_logging)
workflow.add_node("emergency_response", emergency_response)
workflow.add_node("civil_defense_response", civil_defense_response)
workflow.add_node("public_works_response", public_works_response)
workflow.add_node("get_human_verification", get_human_verification)
workflow.add_node("send_email_alert", send_email_alert)
workflow.add_node("handle_no_approval", handle_no_approval)

# Add edges
workflow.add_edge("get_weather", "social_media_monitoring")
workflow.add_edge("social_media_monitoring", "analyze_disaster")
workflow.add_edge("analyze_disaster", "assess_severity")
workflow.add_edge("assess_severity", "data_logging")
workflow.add_conditional_edges("data_logging", route_response)

workflow.add_edge("civil_defense_response", "get_human_verification")
workflow.add_edge("public_works_response", "get_human_verification")
workflow.add_conditional_edges("get_human_verification", verify_approval_router)
workflow.add_edge("emergency_response", "send_email_alert")
workflow.add_edge("send_email_alert", END)
workflow.add_edge("handle_no_approval", END)

workflow.set_entry_point("get_weather")

# Compile the workflow
app = workflow.compile()

# %% [markdown]
#  Running the Weather Emergency System

# %% [markdown]
# (a) run_weather_emergency_system(city: str):

# %%
def run_weather_emergency_system(city: str):
    """Initialize and run the weather emergency system for a given city"""
    initial_state = {
        "city": city,
        "weather_data": {},
        "disaster_type": "",
        "severity": "",
        "response": "",
        "messages": [],
        "alerts": [],
        "social_media_reports": [],
        "human_approved": False
    }

    try:
        result = app.invoke(initial_state)
        print(f"Completed weather check for {city}")
        return result
    except Exception as e:
        print(f"Error running weather emergency system: {str(e)}")

# %% [markdown]
# (b) Get Simulated Weather Data:

# %%
def get_simulated_weather_data(scenario: str = "high") -> Dict:
    """Generate simulated weather data for testing different scenarios"""
    scenarios = {
        "high": {
            "weather": "severe thunderstorm with heavy rainfall and strong winds",
            "wind_speed": 32.5,  # Increased for high severity
            "cloud_cover": 95,
            "sea_level": 1015,
            "temperature": 35.5,  # Higher temperature
            "humidity": 90,
            "pressure": 960  # Low pressure indicating severe weather
        },
        "medium": {
            "weather": "moderate rain with gusty winds",
            "wind_speed": 15.2,
            "cloud_cover": 75,
            "sea_level": 1012,
            "temperature": 22.3,
            "humidity": 70,
            "pressure": 1005
        },
        "low": {
            "weather": "light drizzle",
            "wind_speed": 8.5,
            "cloud_cover": 45,
            "sea_level": 1013,
            "temperature": 20.1,
            "humidity": 60,
            "pressure": 1015
        }
    }

    return scenarios.get(scenario.lower(), scenarios["medium"])

# %% [markdown]
# (c) Run Weather Emergency System Test

# %%
def run_weather_emergency_system_test(city: str, scenario: str = "high"):
    """Test the weather emergency system with simulated data"""
    # Pre-populate with simulated data
    initial_state = {
        "city": city,
        "weather_data": get_simulated_weather_data(scenario),
        "disaster_type": "",
        "severity": "",
        "response": "",
        "messages": [],
        "alerts": [],
        "social_media_reports": [],
        "human_approved": False
    }

    try:
        result = app.invoke(initial_state)
        print(f"\nCompleted test weather check for {city} with {scenario} severity scenario")
        return result
    except Exception as e:
        print(f"Error running weather emergency system test: {str(e)}")

# %% [markdown]
# (d) Run Main Function

# %%
def main():
    """Main function to run the weather emergency system"""
    # Set up environment variables

    os.environ["SENDER_EMAIL"] = "asif.ml.developer@gmail.com"  # please no change this
    os.environ["RECEIVER_EMAIL"] = "imransecrets@gmail.com"  # Recipient email you can change and checked
    os.environ["EMAIL_PASSWORD"] = "iulr lsdb glfy pfbs"  # please no change this

    # Add test mode option
    print("\nWeather Emergency Response System")
    print("1. Run normal monitoring")
    print("2. Run test with simulated data")
    choice = input("Select mode (1 or 2): ")

    if choice == "2":
        print("\nSelect test scenario:")
        print("1. High severity (no human verification needed)")
        print("2. Medium severity (requires human verification)")
        print("3. Low severity (requires human verification)")

        scenario_choice = input("Select scenario (1, 2, or 3): ")
        scenario_map = {"1": "high", "2": "medium", "3": "low"}
        scenario = scenario_map.get(scenario_choice, "medium")

        city = input("\nEnter city name for test (default: Lahore): ").strip() or "Lahore"
        print(f"\nRunning test scenario: {scenario.upper()} severity for {city}")
        run_weather_emergency_system_test(city, scenario)
    else:
        def scheduled_check():
            """Function to perform scheduled checks for multiple cities"""
            cities = ['Lahore']  # Add more cities as needed
            print(f"\nStarting scheduled check at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

            for city in cities:
                try:
                    print(f"\nChecking weather conditions for {city}...")
                    run_weather_emergency_system(city)
                    time.sleep(2)  # Brief pause between cities
                except Exception as e:
                    print(f"Error checking {city}: {str(e)}")

        # Schedule checks every minut
        schedule.every(1).minute.do(scheduled_check)
        print("Weather Emergency Response System started.")
        print("Monitoring scheduled for every minute.")

        while True:
            try:
                schedule.run_pending()
                time.sleep(1)
            except KeyboardInterrupt:
                print("\nShutting down Weather Emergency Response System...")
                break
            except Exception as e:
                print(f"Error in main loop: {str(e)}")
                time.sleep(1)

if __name__ == "__main__":
    main()

# %%
from IPython.display import Image, display

try:
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
